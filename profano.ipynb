# %%
import pandas as pd

# %%
df = pd.read_csv('./profano.csv')
df.head()
# Out:
#    Unnamed: 0  edad-actual  edad-morir  hijes-tenes  gestacion-aborto  \
# 0           0           23         130            0                23
# 1           1           23         124            0                22
# 2           2           37         130            1                16
# 3           3           37          85            0                35
# 4           4           25         130            0                10
#
#    gestacion-persona  genero-coincide  morir-cuerpo  morir-redes  \
# 0                 18              100            65            0
# 1                 22              100            43            0
# 2                 18               86            12           11
# 3                 35               98             3           59
# 4                 32              100            33           48
#
#    miedo-propia  miedo-resto  muerte-experiencia  muerte-eutanasia  firstTime  \
# ...

# %%
df[['edad-actual', 'edad-morir']]
# Out:
#       edad-actual  edad-morir
# 0              23         130
# 1              23         124
# 2              37         130
# 3              37          85
# 4              25         130
# ...           ...         ...
# 8116           20         100
# 8117           18          80
# 8118           32          90
# 8119           30          95
# 8120           24          86
#
# [8121 rows x 2 columns]

# %%
len(df[['edad-actual', 'edad-morir']][(df["edad-actual"] == 23) & (df["edad-morir"] == 130)])
# Out:
# 34

# %%
df.max()
# Out:
# Unnamed: 0             8120
# edad-actual             100
# edad-morir              130
# hijes-tenes               1
# gestacion-aborto         42
# gestacion-persona        42
# genero-coincide         100
# morir-cuerpo            100
# morir-redes             100
# miedo-propia            100
# miedo-resto             100
# muerte-experiencia      100
# muerte-eutanasia        100
# firstTime              True
# hijes-gustaria        100.0
# hijes-volveria        100.0
# dtype: object
